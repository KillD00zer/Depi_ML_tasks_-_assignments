# %% [markdown]
# # ***Python Introduction***
#
#
# * Python Intro
# * Python Get Started
# * Python Syntax
# * Python Comments
# * Python Variables

# %% [markdown]
# # Your first Python Program
#
# Now that we have Python up and running, we can write our first Python program.
#
# Let's create a very simple program called Hello World. A `"Hello, World!"` is a simple program that outputs Hello, World! on the screen. Since it's a very simple program, it's often used to introduce a new programming language to beginners.
#
# Type the following code in any text editor or an IDE and save it as `hello_world.py`

# %%
#run this code
print("Hello, world!")  #shift + Enter == Run the current cell
print(150+100)
# Out:
# Hello, world!
# 250

# %% [markdown]
# Then, run the file. You will get the following output.
#
# `Hello, world!`
#
# Congratulations! You just wrote your first program in Python.
#
# As you can see, this was a pretty easy task. This is the beauty of the Python programming language.

# %% [markdown]
# #Python Keywords and Identifiers
#
# In this tutorial, we will learn about keywords (reserved words in Python) and identifiers (names given to variables, functions, etc.).
# ##Python Keywords
#
# Keywords are predefined, reserved words used in Python programming that have special meanings to the compiler.
#
# We cannot use a keyword as a variable name, function name, or any other identifier. They are used to define the syntax and structure of the Python language.
#
# All the keywords except `True, False and None` are in lowercase and they must be written as they are. The list of all the keywords is given below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Looking at all the keywords at once and trying to figure out what they mean might be overwhelming.
#
# If you want to have an overview, here is the complete list of all the keywords with examples.
# Python Identifiers
#
# Identifiers are the name given to variables, classes, methods, etc. For example,
# ```
# language = 'Python'
# ```
# Here, language is a variable (an identifier) which holds the value 'Python'.
#
# We cannot use keywords as variable names as they are reserved names that are built-in to Python. For example,
# ```
# continue = 'Python'
# ```
# The above code is wrong because we have used continue as a variable name. To learn more about variables, visit Python Variables.

# %% [markdown]
# ## Rules for Naming an Identifier
#
# *    Identifiers cannot be a keyword.
# *    Identifiers are case-sensitive.
# *    It can have a sequence of letters and digits. However, it must begin with a letter or _.
# *   The first letter of an identifier cannot be a digit.
# *    It's a convention to start an identifier with a letter rather _.
# *    Whitespaces are not allowed.
#     We cannot use special symbols like !, @, #, $, and so on.

# %% [markdown]
# # Python Comments
# In computer programming, comments are hints that we use to make our code more understandable.
#
# Comments are completely ignored by the interpreter. They are meant for fellow programmers. For example,

# %%
x = "Hello world"
print(x)
number1 = 10
# Out:
# Hello world

# %%
# declare and initialize two variables
num1 = 6
num2 = 9

# print the output
print('This is output')
# Out:
# This is output

# %% [markdown]
# Here, we have used the following comments,
#
#
#
# *  declare and initialize two variables
# *  print the output
#
# ## Types of Comments in Python
#
# In Python, there are two types of comments:
#
#
# 1.   single-line comment
# 2.   multi-line comment

# %% [markdown]
# ## Single-line Comment in Python
#
# A single-line comment starts and ends in the same line. We use the `#` symbol to write a single-line comment. For example,

# %%
# create a variable
name = 'LaVida'
# This a single line comment
# print the value
print(name)
# Out:
# LaVida

# %%
"""tcyvubhinjmkl,dtfyguhjiokcvubhinjo
ytguhbinjmkxfcgvbhjnkm,l
xcfvgbhnjmk,l.;
dfghjkl;"""

''' qwertyuiop[
sdfghjkl;
asdfghjkl;
zxcvbnm,.ipynb_checkpoints/] '''
print(x)
# Out:
# Hello world

# %% [markdown]
# Here, we have created two single-line comments:
#
# 1. create a variable
# 2. print the value
#
# We can also use the single-line comment along with the code.

# %%
name = 'Life' # name is a string

# %% [markdown]
# Here, code before `#` are executed and code after `#` are ignored by the interpreter.

# %% [markdown]
# ## Multi-line Comment in Python
#
# Python doesn't offer a separate way to write multiline comments. However, there are other ways to get around this issue.
#
# We can use `#` at the beginning of each line of comment on multiple lines. For example,
# ```
# # This is a long comment
# # and it extends
# # to multiple lines
# ```
# Here, each line is treated as a single comment, and all of them are ignored.
#
# Another way of doing this is to use triple quotes, either `'''` or `"""`.
#
# These triple quotes are generally used for multi-line strings. But if we do not assign it to any variable or function, we can use it as a comment.
#
# The interpreter ignores the string that is not assigned to any variable or function.
#
# Let's see an example,
# ```
# ''' This is also a
# perfect example of
# multi-line comments '''
# ```
# Here, the multiline string isn't assigned to any variable, so it is ignored by the interpreter. Even though it is not technically a multiline comment, it can be used as one.

# %% [markdown]
# ## Use of Python Comment
#
# 1. Make Code Easier to Understand
#
# If we write comments in our code, it will be easier for future reference.
#
# Also, it will be easier for other developers to understand the code.
#
# 2. Using Comments for Debugging
#
# If we get an error while running the program, we can comment the line of code that causes the error instead of removing it. For example,

# %%
print('Python')

# print('Error Line )

print('Django')
# Out:
# Python
# Django

# %% [markdown]
# Here, `print('Error Line)` was causing an error so we have changed it to a comment. Now, the program runs without any errors.
#
# This is how comments can be a valuable debugging tool.
#
# ### *Note*:

# %%
'''Always use comments to explain why we did something rather than how we did something.
Comments shouldn't be a substitute to explain poorly written code.
'''
# Out:
# "Always use comments to explain why we did something rather than how we did something.\nComments shouldn't be a substitute to explain poorly written code.\n"

# %% [markdown]
# # ***Python Variables***
#
# Variables are containers for storing data values.
#
# Variable is a name that is used to refer to memory location. Python variable is also known as an identifier and used to hold value.
#
# In Python, we don't need to specify the type of variable because Python is a infer language and smart enough to get variable type.
#
# Variable names can be a group of both the letters and digits, but they have to begin with a letter or an underscore.
#
# It is recommended to use lowercase letters for the variable name. Rahul and rahul both are two different variables.
#
#
# ### Creating Variables
#
# Python has no command for declaring a variable.
#
# A variable is created the moment you first assign a value to it.

# %%
x = 5
y = "Sarah"
print(x)
print(y)
# Out:
# 5
# Sarah

# %% [markdown]
# Variables do not need to be declared with any particular type, and can even change type after they have been set.

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %% [markdown]
# ### Casting
#
# If you want to specify the data type of a variable, this can be done with casting.

# %%
x = str(9)    # x will be '3'
y = int(3.6)    # y will be 3
z = float(3)  # z will be 3.0

# %%
print(type(x))
print(type(y))
print(type(z))
print(x, y , z)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# 9 3 3.0

# %%
complex1 = 5 + 8j
print(complex1, type(complex1))
# Out:
# (5+8j) <class 'complex'>

# %% [markdown]
# ## Single or Double Quotes?
#
# String variables can be declared either by using single or double quotes:

# %%
x = "John"
# is the same as
x = 'Hammed'
x
# Out:
# 'Hammed'

# %% [markdown]
# ## Case-Sensitive
#
# Variable names are case-sensitive.

# %%
#Example
#This will create two variables:
a = 4
A = "Sally"
#A will not overwrite a
print(a, A)
# Out:
# 4 Sally

# %%
variable= 5
Variable = 5
VARIABLE = 5

# %% [markdown]
# ## Variable Names
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume). Rules for Python variables:
#
# * A variable name must start with a letter or the underscore character
# * A variable name cannot start with a number
# * A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# * Variable names are case-sensitive (age, Age and AGE are three different variables)
# * A variable name cannot be any of the Python keywords.

# %%
#Legal variable names:
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"
myvariablename = 5

# %% [markdown]
# Example
#
# ### Illegal variable names:
# ```
# 2myvar = "John"
# my-var = "John"
# my var = "John"
# ```
# Remember that variable names are case-sensitive

# %% [markdown]
# ## Multi Words Variable Names
#
# Variable names with more than one word can be difficult to read.
#
# There are several techniques you can use to make them more readable:
# ### Camel Case
#
# Each word, except the first, starts with a capital letter:
#
# ```myVariableName = "John"```
# ### Pascal Case
#
# Each word starts with a capital letter:
#
# ```MyVariableName = "John"```
# ### Snake Case
#
# Each word is separated by an underscore character:
#
# ```my_variable_name = "John"```

# %% [markdown]
# ## Python Variables - Assign Multiple Values
#
# ### Many Values to Multiple Variables
#
# Python allows you to assign values to multiple variables in one line:

# %%
#Packing
x, y, z, W = "Orange", "Banana", "Cherry" , 1+6
print(x)
print(y)
print(z)
print(W)
# Out:
# Orange
# Banana
# Cherry
# 7

# %% [markdown]
# ### *Note:*
#  Make sure the number of variables matches the number of values, or else you will get an error.

# %% [markdown]
# ### One Value to Multiple Variables
#
# And you can assign the same value to multiple variables in one line:

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# # Different Types of Data Types
#
# 1- numbers (Integers, float , complex)
#
# 2-Letters or words (string)
#
# 3- Booleans (True, Fales)
#
# 4- Collections:
#
#      1.list    ---> []  ordered or indexed ,,, changable or mutable ,,, allow duplicates
#
#      2.Tuple   --->  () ordered or indexed ,,, unchangable or immutable ,,, allow duplicates
#
#      3.set    ---> {} unordered or unindexed ,,, unchangable or immutable ,,, doesn't allow duplicates
#
#      4.dictionary ---> {key = value} ,,, ordered or indexed by the key ,,, changable or mutable ,,, No duplicates

# %%
list1 = [4 , 5.5 ,"Ahmed", True, [1,2,3,4], (0,1,2), {1.2,2}, 4, 8]
tuple1 = (4 , 5 ,"Ahmed", True, [1,2,3,4], (0,1,2), {1.2,2}, 4)
set1 = {4 , 5 ,"Ahmed", True, 4}
print(list1)
print(tuple1)
print(set1)
# Out:
# [4, 5.5, 'Ahmed', True, [1, 2, 3, 4], (0, 1, 2), {1.2, 2}, 4, 8]
# (4, 5, 'Ahmed', True, [1, 2, 3, 4], (0, 1, 2), {1.2, 2}, 4)
# {True, 'Ahmed', 4, 5}

# %%
tuple1 = list(tuple1)
tuple1[2] = "Mohamed"
tuple1 = tuple(x)
tuple1
# Out:
# ('O', 'r', 'a', 'n', 'g', 'e')

# %%
#casting
list()
tuple()
set()
dict()
# Out:
# {}

# %% [markdown]
# ### Unpack a Collection
#
# If you have a collection of values in a list, tuple etc. Python allows you to extract the values into variables. This is called unpacking.

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
list1 = ["apple", "banana", "cherry", 4 , True , 4+1j]
list1
# Out:
# ['apple', 'banana', 'cherry', 4, True, (4+1j)]

# %% [markdown]
# ### Output Variables
#
# The Python `print()` function is often used to output variables.

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %% [markdown]
# In the `print()` function, you output multiple variables, separated by a comma:

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %% [markdown]
# You can also use the `+` operator to output multiple variables:

# %%
#Concatination
x = "Python"
y = "is"
z = "awesome"

print(x +' '+  y + " " + z) #concatanation
# Out:
# Python is awesome

# %% [markdown]
# Notice the space character after "Python " and "is ", without them the result would be "Pythonisawesome".
#
# For numbers, the `+` character works as a mathematical operator:

# %%
x = 5
y = 10
print(x + y)
# Out:
# 15

# %% [markdown]
# In the `print()` function, when you try to combine a string and a number with the + operator, Python will give you an error:
# Example
# ```
# x = 5
# y = "John"
# print(x + y)
# ```
#
# The best way to output multiple variables in the `print()` function is to separate them with commas, which even support different data types:

# %%
x = 5
y = "John"
print(x , y)
# Out:
# 5 John

# %%
x = 5
y = "John"
print(str(x) + ' '+ y) # equavalent to {print(str(x) ,y) }
# Out:
# 5 John

# %% [markdown]
# # Python Operators
#
# 1- Arithmetic Op.
#
# (+ , - , * , / , % modulus , // floor division  , ** power)
#
# 2- Assignment Op.
#
# (=, += , -= )
#
# 3- Comparison Op.
#
# (==, != , > , < , >= , <=)
#
# 4- Logical Op.
#
# (and , or  , not )
#
# 5- Idetity Op.
#
# (is , is not)
#
# 6- Memebership Op.
#
# (in , not in )
#
# 7- Bitwise Op.
#
# AND  >> &
#
# OR   >> |
#
# XOR  >> ^
#
# NOT  >> ~

# %%
#Arithmetic Op.
print(5+5)
print(5-5)
print(5*5)
print(5/5)
print(5%5)
print(5**2)
print(15//2)
# Out:
# 10
# 0
# 25
# 1.0
# 0
# 25
# 7

# %%
#Assignment Op.
x = 5
print(x)
x += 3 # x=x+3
print(x)
x -= 3 # x=x-3
print(x)
x *= 3 # x=x*3
print(x)
x /=3 # x=x/3
print(x)
x %=3 # x=x%3
print(x)
x //=3 #x=x//3
print(x)
x **=3 #x=x**3
print(x)
print(x := 3) # x = 3
# Out:
# 5
# 8
# 5
# 15
# 5.0
# 2.0
# 0.0
# 0.0
# 3

# %%
x, y = 5, 10  
#Comparsion Operator
print(x ,'|', y)
print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)
# Out:
# 5 | 10
# False
# True
# False
# True
# False
# True

# %%
#Logic Operator
print(x < 5 and x < 10)  #both sides are true
print(x < 5 or x < 10)  #either sides are true
print(not(x < 5 and x <10))  #reverse of the result from the parethness
# Out:
# False
# True
# True

# %%
#Identity Operator
x, y = 5, 10  

print(type(x) is type(y)) #true if x is the same of y (x == y) 
print(x is not y) #true if x isn't the same of y  (x != y)
# Out:
# True
# True

# %%
print(fruits, type(fruits))
print(list1, type(list1))
# Out:
# ['apple', 'banana', 'cherry'] <class 'list'>
# ['apple', 'banana', 'cherry', 4, True, (4+1j)] <class 'list'>

# %%
print(type(fruits) is type(list1))
print(fruits is not list1)
# Out:
# True
# True

# %%
#Membership Operator 
print('apple' in fruits)
print("orange" not in fruits)
# Out:
# True
# True

# %%
#Bitwise Operator 
'''
6 = 0110
&
3 = 0011
___________
2 = 0010
'''
'''
6 = 0110
^
3 = 0011
___________
5 = 0101
'''
print( 6 & 3 )
print( 6 ^ 3 )
# Out:
# 2
# 5

# %% [markdown]
# # Strings
#
# strings are arrays of bytes representing unicode characters, However, python dosn't have a charater data type.
# a single charater is simply a string with a lenght of 1.
# square brackets can be used to access elements of the string
#
#  int arr [5];
#  {1,2,3,4,5}
#
#  arr[1];

# %%
word = "Hello World"
#string[start=0 : End+1 : step=1]

print(word[0]) #H
print(word[-1]) #d
print(word[-5:]) #World
print(word[6:])  #World
print(word[:5]) #
print(word[3:6]) #
print(word[-9:-2]) #
len(word)
# Out:
# H
# d
# World
# World
# Hello
# lo
# llo Wor
# 11

# %%
word1 ="Hello Batch Three of Secure Way Company"
lis = word1.split(" ")
print(lis)
lis[0]
# Out:
# ['Hello', 'Batch', 'Three', 'of', 'Secure', 'Way', 'Company']
# 'Hello'

# %%
#f-String
age = 40 
txt = f"My name is samar, and I am {age} years old"  #placeholder
print(txt)
# Out:
# My name is samar, and I am 40 years old

# %%
price = 59
txt1 = f"The price is {price:.10f} dollars" #modifiers : + legel formatting type
print(txt1)
print(f"The price is {price:.10f} dollars" )
f"The price is {price:.10f} dollars"
# Out:
# The price is 59.0000000000 dollars
# The price is 59.0000000000 dollars
# 'The price is 59.0000000000 dollars'

# %%
price = 59
txt1 = f"The price is  {20*59} dollars" #operations
print(txt1)
# Out:
# The price is  1180 dollars

# %%
txt1 = "The price is  {0} dollars" #operations curly brackets
print(txt1.format(59,50,60))
# Out:
# The price is  59 dollars

# %%
txt2 = "My name is {0}, I'm {2} years old, and I'm working as {1}"
print(txt2.format("Amr", "Engineer",30))
# Out:
# My name is Amr, I'm 30 years old, and I'm working as Engineer

# %%
#Escape Characters 

#1- \" or \' single Quote
print( "we are a communication engineers at {Yemen Mobil} and we work as a \"Full-time\" Engineer ")
#OR
print( 'we are a communication engineers at {Yemen Mobil} and we work as a "Full-time" Engineer')
print("____________________________________________")

#2- \\ backslah
print("This will insert one \\ (backslach)")
print("____________________________________________")

#3- \n : new line 
print("Hello\nWorld")
print("____________________________________________")

#4- \r carriage return == (اللي قبله كله)
print("Hello\rWorld")
print("____________________________________________")

#5- \t tab 
print("Hello\tWorld")  
print("____________________________________________")

#6- \b backspace (eraes one charater)
print("Hello \bWorld")
# Out:
# we are a communication engineers at {Yemen Mobil} and we work as a "Full-time" Engineer
# we are a communication engineers at {Yemen Mobil} and we work as a "Full-time" Engineer
# ____________________________________________
# This will insert one \ (backslach)
# ____________________________________________
# Hello
# World
# ____________________________________________
# World
# ____________________________________________
# Hello	World
# ____________________________________________
# HelloWorld

# %%
list1 = list((12,2,5,True)) # list Constructor
list2 = [12,2,5,True]
print(list1, list2)
# Out:
# [12, 2, 5, True] [12, 2, 5, True]

# %%
tuple1 = (1,2,"Amr")
set1 = {1,2,3,"Amr"}
tuple_one_element = ("Samar",)
string_notTuple = ("Samar")
print(tuple1)
print(set1)
print(type(tuple_one_element), type(string_notTuple))
# Out:
# (1, 2, 'Amr')
# {1, 2, 3, 'Amr'}
# <class 'tuple'> <class 'str'>

# %%
Car = {
    "brand" : ["KIA", "Ford"], 
    "model" : ["Sportage", "Mustang"],
    "year" : [2024, 2025]
}
Car
# Out:
# {'brand': ['KIA', 'Ford'],
#  'model': ['Sportage', 'Mustang'],
#  'year': [2024, 2025]}

# %%
import pandas as pd
df = pd.DataFrame(Car)
df
# Out:
#   brand     model  year
# 0   KIA  Sportage  2024
# 1  Ford   Mustang  2025

# %%
dict3 = dict(brand= ["KIA", "Ford"], model= ["Sportage", "Mustang"] , year = [2024, 2025]) # Dict Constructor
dict3
# Out:
# {'brand': ['KIA', 'Ford'],
#  'model': ['Sportage', 'Mustang'],
#  'year': [2024, 2025]}

# %%
Car["brand"][0]
# Out:
# 'KIA'

# %%
Car.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
Car.values()
# Out:
# dict_values([['KIA', 'Ford'], ['Sportage', 'Mustang'], [2024, 2025]])

# %%
Car.items()
# Out:
# dict_items([('brand', ['KIA', 'Ford']), ('model', ['Sportage', 'Mustang']), ('year', [2024, 2025])])

# %%
Car["Color"]= ["Red", "Black"]
Car
# Out:
# {'brand': ['KIA', 'Ford'],
#  'model': ['Sportage', 'Mustang'],
#  'year': [2024, 2025],
#  'Color': ['Red', 'Black']}

# %%
import pandas as pd 
df = pd.DataFrame(Car)
df
# Out:
#   brand     model  year  Color
# 0   KIA  Sportage  2024    Red
# 1  Ford   Mustang  2025  Black

# %% [markdown]
# # JSON FILE
#
# nested dictionary == dictionary have internal dictionary inside it

# %%
myfamily1 = {
    "Child1": {
        "name":"Mohamed", 
        "age": 20
    },
    "Child2": {
        "name": "Amir",
        "age": 30
    }, 
    "Child3": {
        "name": "Ahmed", 
        "age" :25
    }
}
myfamily1
# Out:
# {'Child1': {'name': 'Mohamed', 'age': 20},
#  'Child2': {'name': 'Amir', 'age': 30},
#  'Child3': {'name': 'Ahmed', 'age': 25}}

# %%
jsonfile = pd.DataFrame(myfamily1)
jsonfile
# Out:
#        Child1 Child2 Child3
# name  Mohamed   Amir  Ahmed
# age        20     30     25

# %%
myfamily = {
    'father' : {
        'name' : "Ahmed", 
        'age': 65, 
        'work' : 'Doctor'
    }, 
    'mother' : {
        'name' : "Salma", 
        'age': 60, 
        'work' : 'Doctor'
    }, 
    'Child': {
        'name' : "Amr", 
        'age': 25, 
        'work' : {"numberOfJobs" : 2, "kindofJob" : "part-time"}
}
}
myfamily
# Out:
# {'father': {'name': 'Ahmed', 'age': 65, 'work': 'Doctor'},
#  'mother': {'name': 'Salma', 'age': 60, 'work': 'Doctor'},
#  'Child': {'name': 'Amr',
#   'age': 25,
#   'work': {'numberOfJobs': 2, 'kindofJob': 'part-time'}}}

# %%
json = pd.DataFrame(myfamily)
json
# Out:
#       father  mother                                          Child
# name   Ahmed   Salma                                            Amr
# age       65      60                                             25
# work  Doctor  Doctor  {'numberOfJobs': 2, 'kindofJob': 'part-time'}
